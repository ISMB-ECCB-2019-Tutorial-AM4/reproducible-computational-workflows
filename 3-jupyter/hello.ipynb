# %% [markdown]
# # Hello Basel!
#
# This is an example of a markdown cell in Jupyter.
#
# All standard markdown syntax will render, including headers, __emphasis__, [links](https://www.iscb.org/ismbeccb2019), and `code`.

# %% [markdown]
# This cell won't run unless we're using a python2 kernel. Fortunately, it's easy to select a kernel to use with Jupyter.

# %%
print "Hello ISMB"
# Out:
#   File "<ipython-input-2-6e198d77bc7d>", line 1
#     print "Hello ISMB"
#                      ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print("Hello ISMB")?
