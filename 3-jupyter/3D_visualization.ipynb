# %% [markdown]
# # 3D Visualization with py3Dmol
# This brief tutorial demonstrates how to visualize 3D structures using the [py3Dmol](http://3dmol.csb.pitt.edu/index.html) Jupyter Notebook widget.
#
# 3Dmol.js: molecular visualization with WebGL, N. Rego, D. Koes, [Bioinformatics (2015) 31, 1322–1324](https://doi.org/10.1093/bioinformatics/btu829)
#
# To learn more, check out the 3D-visualization tutorial in [mmtf-workshop-2018](https://github.com/sbl-sdsc/mmtf-workshop-2018)
#
# Also, check out the [py3Dmol tutorial](http://nbviewer.jupyter.org/github/3dmol/3Dmol.js/blob/9050b97144e81f065df7eecc87ba9a16723ab14b/py3Dmol/examples.ipynb) for additional features.

# %%
import py3Dmol

# %% [markdown]
# ## Visualize a Structure by PDB Id
# Here we fetch a Hemoglobin structure [5WOG](https://www.rcsb.org/structure/5WOG).

# %%
viewer = py3Dmol.view(query='pdb:5WOG')
viewer.show()
# Out:
# <div id="3dmolviewer_1562380051478258"  style="position: relative; width: 640px; height: 480px">
#         <p id="3dmolwarning_1562380051478258" style="background-color:#ffcccc;color:black">You appear to be running in JupyterLab (or JavaScript failed to load for some other reason).  You need to install the 3dmol extension: <br>
#         <tt>jupyter labextension install jupyterlab_3dmol</tt></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#       resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://3dmol.csb.pitt.edu/build/3Dmol.js');
# }
#
# var viewer_1562380051478258 = null;
# var warn = document.getElementById("3dmolwarning_1562380051478258");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_1562380051478258 = $3Dmol.createViewer($("#3dmolviewer_1562380051478258"),{backgroundColor:"white"});
# $3Dmol.download("pdb:5WOG", viewer_1562380051478258, {}, function() {
# viewer_1562380051478258.render();
# })
# });
# </script>

# %% [markdown]
# ## Apply Styles
# ### Apply a style to a chain
# Here we select chain A and apply a cartoon style.

# %%
viewer.setStyle({'chain':'A'},{'cartoon': {'color': 'orange'}})
viewer.show()
# Out:
# <div id="3dmolviewer_156238005316686"  style="position: relative; width: 640px; height: 480px">
#         <p id="3dmolwarning_156238005316686" style="background-color:#ffcccc;color:black">You appear to be running in JupyterLab (or JavaScript failed to load for some other reason).  You need to install the 3dmol extension: <br>
#         <tt>jupyter labextension install jupyterlab_3dmol</tt></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#       resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://3dmol.csb.pitt.edu/build/3Dmol.js');
# }
#
# var viewer_156238005316686 = null;
# var warn = document.getElementById("3dmolwarning_156238005316686");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_156238005316686 = $3Dmol.createViewer($("#3dmolviewer_156238005316686"),{backgroundColor:"white"});
# $3Dmol.download("pdb:5WOG", viewer_156238005316686, {}, function() {
# 	viewer_156238005316686.setStyle({"chain": "A"},{"cartoon": {"color": "orange"}});
# viewer_156238005316686.render();
# })
# });
# </script>

# %% [markdown]
# ### Apply a style to a list of  chains and add labels
# Use a list to select to multiple chains.

# %%
viewer.setStyle({'chain':['A','B']},{'cartoon': {'color': 'orange'}}) # alpha subunits of hemoglobin

viewer.addLabel('alpha subunits', {'fontColor':'orange', 'backgroundColor':'lightgray'},
                {'chain': ['A','B']})

viewer.setStyle({'chain':['C','D']},{'cartoon': {'color': 'blue'}}) # beta subunits of hemoglobin

viewer.addLabel('beta subunits', {'fontColor':'blue', 'backgroundColor':'lightgray'},
                {'chain': ['C','D']})
viewer.show()
# Out:
# <div id="3dmolviewer_15623800546843252"  style="position: relative; width: 640px; height: 480px">
#         <p id="3dmolwarning_15623800546843252" style="background-color:#ffcccc;color:black">You appear to be running in JupyterLab (or JavaScript failed to load for some other reason).  You need to install the 3dmol extension: <br>
#         <tt>jupyter labextension install jupyterlab_3dmol</tt></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#       resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://3dmol.csb.pitt.edu/build/3Dmol.js');
# }
#
# var viewer_15623800546843252 = null;
# var warn = document.getElementById("3dmolwarning_15623800546843252");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_15623800546843252 = $3Dmol.createViewer($("#3dmolviewer_15623800546843252"),{backgroundColor:"white"});
# $3Dmol.download("pdb:5WOG", viewer_15623800546843252, {}, function() {
# 	viewer_15623800546843252.setStyle({"chain": "A"},{"cartoon": {"color": "orange"}});
# 	viewer_15623800546843252.setStyle({"chain": ["A", "B"]},{"cartoon": {"color": "orange"}});
# 	viewer_15623800546843252.addLabel("alpha subunits",{"fontColor": "orange", "backgroundColor": "lightgray"},{"chain": ["A", "B"]});
# 	viewer_15623800546843252.setStyle({"chain": ["C", "D"]},{"cartoon": {"color": "blue"}});
# 	viewer_15623800546843252.addLabel("beta subunits",{"fontColor": "blue", "backgroundColor": "lightgray"},{"chain": ["C", "D"]});
# viewer_15623800546843252.render();
# })
# });
# </script>

# %% [markdown]
# ### Apply a style by residue name (resn)
# Show heme as spheres.

# %%
viewer.setStyle({'resn': 'HEM'},{'sphere': {'colorscheme': 'greenCarbon'}})
viewer.show()
# Out:
# <div id="3dmolviewer_156238005599552"  style="position: relative; width: 640px; height: 480px">
#         <p id="3dmolwarning_156238005599552" style="background-color:#ffcccc;color:black">You appear to be running in JupyterLab (or JavaScript failed to load for some other reason).  You need to install the 3dmol extension: <br>
#         <tt>jupyter labextension install jupyterlab_3dmol</tt></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#       resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://3dmol.csb.pitt.edu/build/3Dmol.js');
# }
#
# var viewer_156238005599552 = null;
# var warn = document.getElementById("3dmolwarning_156238005599552");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_156238005599552 = $3Dmol.createViewer($("#3dmolviewer_156238005599552"),{backgroundColor:"white"});
# $3Dmol.download("pdb:5WOG", viewer_156238005599552, {}, function() {
# 	viewer_156238005599552.setStyle({"chain": "A"},{"cartoon": {"color": "orange"}});
# 	viewer_156238005599552.setStyle({"chain": ["A", "B"]},{"cartoon": {"color": "orange"}});
# 	viewer_156238005599552.addLabel("alpha subunits",{"fontColor": "orange", "backgroundColor": "lightgray"},{"chain": ["A", "B"]});
# 	viewer_156238005599552.setStyle({"chain": ["C", "D"]},{"cartoon": {"color": "blue"}});
# 	viewer_156238005599552.addLabel("beta subunits",{"fontColor": "blue", "backgroundColor": "lightgray"},{"chain": ["C", "D"]});
# 	viewer_156238005599552.setStyle({"resn": "HEM"},{"sphere": {"colorscheme": "greenCarbon"}});
# viewer_156238005599552.render();
# })
# });
# </script>

# %% [markdown]
# ## Select binding site residues by proximity
# Here we select all residues within 5 A of the HEM in chain A.

# %%
# remove labels and reset styles
viewer.removeAllLabels()
viewer.setStyle({'line':{}})

# select by distance
selection = {'resn':'HEM', 'chain':'A', 'byres':'true', 'expand': 5}

# set styles
viewer.setStyle(selection,{'stick':{'colorscheme':'orangeCarbon'}})
viewer.setStyle({'chain': 'A', 'resn': 'HEM'},{'sphere': {'colorscheme': 'lightgreenCarbon'}})
viewer.zoomTo(selection)
viewer.show()
# Out:
# <div id="3dmolviewer_15623800572650921"  style="position: relative; width: 640px; height: 480px">
#         <p id="3dmolwarning_15623800572650921" style="background-color:#ffcccc;color:black">You appear to be running in JupyterLab (or JavaScript failed to load for some other reason).  You need to install the 3dmol extension: <br>
#         <tt>jupyter labextension install jupyterlab_3dmol</tt></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#       resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://3dmol.csb.pitt.edu/build/3Dmol.js');
# }
#
# var viewer_15623800572650921 = null;
# var warn = document.getElementById("3dmolwarning_15623800572650921");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_15623800572650921 = $3Dmol.createViewer($("#3dmolviewer_15623800572650921"),{backgroundColor:"white"});
# $3Dmol.download("pdb:5WOG", viewer_15623800572650921, {}, function() {
# 	viewer_15623800572650921.setStyle({"chain": "A"},{"cartoon": {"color": "orange"}});
# 	viewer_15623800572650921.setStyle({"chain": ["A", "B"]},{"cartoon": {"color": "orange"}});
# 	viewer_15623800572650921.addLabel("alpha subunits",{"fontColor": "orange", "backgroundColor": "lightgray"},{"chain": ["A", "B"]});
# 	viewer_15623800572650921.setStyle({"chain": ["C", "D"]},{"cartoon": {"color": "blue"}});
# 	viewer_15623800572650921.addLabel("beta subunits",{"fontColor": "blue", "backgroundColor": "lightgray"},{"chain": ["C", "D"]});
# 	viewer_15623800572650921.setStyle({"resn": "HEM"},{"sphere": {"colorscheme": "greenCarbon"}});
# 	viewer_15623800572650921.removeAllLabels();
# 	viewer_15623800572650921.setStyle({"line": {}});
# 	viewer_15623800572650921.setStyle({"resn": "HEM", "chain": "A", "byres": "true", "expand": 5},{"stick": {"colorscheme": "orangeCarbon"}});
# 	viewer_15623800572650921.setStyle({"chain": "A", "resn": "HEM"},{"sphere": {"colorscheme": "lightgreenCarbon"}});
# 	viewer_15623800572650921.zoomTo({"resn": "HEM", "chain": "A", "byres": "true", "expand": 5});
# viewer_15623800572650921.render();
# })
# });
# </script>

# %% [markdown]
# ## Create a surface
# In the structure below (HLA complex with antigen peptide pVR), we add a solvent excluded surface (SES) to the heavy chain to highlight the binding pocket for the antigen peptide (rendered as spheres).

# %%
viewer = py3Dmol.view(query='pdb:5XS3')

heavychain = {'chain':'A'}
lightchain = {'chain':'B'}
antigen = {'chain':'C'}

viewer.setStyle(heavychain,{'cartoon':{'color':'blue'}})
viewer.setStyle(lightchain,{'cartoon':{'color':'yellow'}})
viewer.setStyle(antigen,{'sphere':{'colorscheme':'orangeCarbon'}})

viewer.addSurface(py3Dmol.SES,{'opacity':0.9,'color':'lightblue'}, heavychain)
viewer.show()
# Out:
# <div id="3dmolviewer_1562380058635402"  style="position: relative; width: 640px; height: 480px">
#         <p id="3dmolwarning_1562380058635402" style="background-color:#ffcccc;color:black">You appear to be running in JupyterLab (or JavaScript failed to load for some other reason).  You need to install the 3dmol extension: <br>
#         <tt>jupyter labextension install jupyterlab_3dmol</tt></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#       resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://3dmol.csb.pitt.edu/build/3Dmol.js');
# }
#
# var viewer_1562380058635402 = null;
# var warn = document.getElementById("3dmolwarning_1562380058635402");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_1562380058635402 = $3Dmol.createViewer($("#3dmolviewer_1562380058635402"),{backgroundColor:"white"});
# $3Dmol.download("pdb:5XS3", viewer_1562380058635402, {}, function() {
# 	viewer_1562380058635402.setStyle({"chain": "A"},{"cartoon": {"color": "blue"}});
# 	viewer_1562380058635402.setStyle({"chain": "B"},{"cartoon": {"color": "yellow"}});
# 	viewer_1562380058635402.setStyle({"chain": "C"},{"sphere": {"colorscheme": "orangeCarbon"}});
# 	viewer_1562380058635402.addSurface(4,{"opacity": 0.9, "color": "lightblue"},{"chain": "A"});
# viewer_1562380058635402.render();
# })
# });
# </script>

# %% [markdown]
# ### Create an image
# After you orient the structure in the cell above, run the following cell to create an image.
#
# Save the image:
# * Shift+Right Click to open Browser menu (Windows)
# * Shift+Ctrl+Click to open Browser menu (MacOS)

# %%
viewer.png()
# Out:
# <img id="img_1562380058635402">
#             <script>
#             var png = viewer_1562380058635402.pngURI()
#             $('#img_1562380058635402').attr('src', png)
#             </script>

# %% [markdown]
# Author: Peter W. Rose, pwrose@ucsd.edu, UC San Diego, July 5, 2019
